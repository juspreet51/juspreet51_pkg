# %%
from juspreet51 import visualizations as js51_viz

# %%
# Taking housing dataset example, and plotting pie chart for ocean_proximity value
# Replace "https://...link/..." with data of your choice
import pandas as pd
house_val = pd.read_csv('../datasets/housing.csv')

js51_viz.draw_piechart(house_val["ocean_proximity"])
